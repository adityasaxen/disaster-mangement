# %% [markdown]
# # 🔮 Predictions
# ## Generating Dashboard Insights
#
# This notebook is part of the Disaster Prediction System MCA Project.

# %%
import joblib
import json
import pandas as pd

# Loading models and generating mock dashboard results
# In a real scenario, this would iterate through test data
output_data = {
    'cyclone': {'accuracy': 0.88, 'status': 'Models Ready'},
    'drought': {'accuracy': 0.92, 'status': 'Models Ready'},
    'tornado': {'accuracy': 0.85, 'status': 'Models Ready'}
}


with open('dashboard_data.json', 'w') as f:
    json.dump(output_data, f)
print('Dashboard data generated.')


# Replace these values with your actual model outputs
results = {
    "cyclone": { "risk": "82%", "intensity": 3, "trend": [20, 45, 82, 35, 15] },
    "drought": { "level": "Moderate", "index": 2.4, "precip": [150, 45, 250, 35] },
    "tornado": { "category": "High", "prob": 72, "hotspots": [10, 25, 65] }
}

with open('dashboard_data.json', 'w') as f:
    json.dump(results, f)
# Out:
# Dashboard data generated.
